# %%
#Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from scipy.stats import linregress
import seaborn as sns
import os

# %%
all_df = pd.read_csv("Output_Files/genre.csv")

all_df.head(50)
# Out:
#     Unnamed: 0                                    Title          Genre_1  \
# 0            0             Star Wars: The Force Awakens           Action
# 1            1                           Jurassic World           Action
# 2            2                                Furious 7           Action
# 3            3                  Avengers: Age of Ultron           Action
# 4            4                                  Minions           Family
# 5            5                                  Spectre           Action
# 6            6                               Inside Out        Animation
# 7            7       Mission: Impossible - Rogue Nation           Action
# 8            8    The Hunger Games: Mockingjay - Part 2           Action
# 9            9                              The Martian            Drama
# 10          10                     Fifty Shades of Grey            Drama
# 11          11                               Cinderella          Romance
# 12          12                             The Revenant          Western
# 13          13                                  Ant-Man  Science Fiction
# 14          14                              San Andreas           Action
# 15          15                     Hotel Transylvania 2           Family
# 16          16                       Terminator Genisys  Science Fiction
# 17          17                       Mad Max: Fury Road           Action
# 18          18                                     Home          Fantasy
# 19          19                        The Good Dinosaur        Adventure
# 20          20               Captain America: Civil War        Adventure
# 21          21             Rogue One: A Star Wars Story           Action
# 22          22                             Finding Dory        Adventure
# 23          23                                 Zootopia        Animation
# 24          24                          The Jungle Book        Adventure
# 25          25                  The Secret Life of Pets        Adventure
# 26          26       Batman v Superman: Dawn of Justice           Action
# 27          27  Fantastic Beasts and Where to Find Them        Adventure
# 28          28                                 Deadpool           Action
# 29          29                            Suicide Squad           Action
# 30          30                                    Moana        Adventure
# 31          31                           Doctor Strange           Action
# 32          32                                     Sing           Family
# 33          33                        X-Men: Apocalypse           Action
# 34          34                          Kung Fu Panda 3           Action
# 35          35                               La La Land           Comedy
# 36          36                                 Warcraft           Action
# 37          37                             Jason Bourne           Action
# 38          38                Ice Age: Collision Course        Adventure
# 39          39                 Star Wars: The Last Jedi  Science Fiction
# 40          40                     Beauty and the Beast           Family
# 41          41                  The Fate of the Furious           Action
# 42          42                          Despicable Me 3           Action
# 43          43           Jumanji: Welcome to the Jungle           Action
# 44          44                   Spider-Man: Homecoming           Action
# 45          45                           Wolf Warrior 2              War
# 46          46           Guardians of the Galaxy Vol. 2        Adventure
# 47          47                           Thor: Ragnarok           Action
# 48          48                             Wonder Woman           Action
# 49          49                                     Coco           Family
#
#       Genre_2          Genre_3          Genre_4          Genre_5    Genre_6  \
# 0   Adventure  Science Fiction          Fantasy              NaN        NaN
# 1   Adventure  Science Fiction         Thriller              NaN        NaN
# 2    Thriller              NaN              NaN              NaN        NaN
# 3   Adventure  Science Fiction              NaN              NaN        NaN
# 4   Animation        Adventure           Comedy              NaN        NaN
# 5   Adventure         Thriller              NaN              NaN        NaN
# 6      Family        Adventure            Drama           Comedy        NaN
# 7   Adventure              NaN              NaN              NaN        NaN
# 8   Adventure  Science Fiction              NaN              NaN        NaN
# 9   Adventure  Science Fiction              NaN              NaN        NaN
# 10    Romance         Thriller              NaN              NaN        NaN
# 11    Fantasy           Family            Drama              NaN        NaN
# 12      Drama        Adventure              NaN              NaN        NaN
# 13     Action        Adventure              NaN              NaN        NaN
# 14      Drama         Thriller              NaN              NaN        NaN
# 15  Animation           Comedy          Fantasy              NaN        NaN
# 16     Action         Thriller        Adventure              NaN        NaN
# 17  Adventure  Science Fiction              NaN              NaN        NaN
# 18     Comedy        Animation  Science Fiction           Family        NaN
# 19  Animation           Family              NaN              NaN        NaN
# 20     Action  Science Fiction              NaN              NaN        NaN
# 21  Adventure  Science Fiction              NaN              NaN        NaN
# 22  Animation           Comedy           Family              NaN        NaN
# 23  Adventure           Family           Comedy              NaN        NaN
# 24      Drama           Family          Fantasy              NaN        NaN
# 25     Comedy        Animation           Family              NaN        NaN
# 26  Adventure          Fantasy              NaN              NaN        NaN
# 27    Fantasy              NaN              NaN              NaN        NaN
# 28  Adventure           Comedy              NaN              NaN        NaN
# 29  Adventure            Crime          Fantasy  Science Fiction        NaN
# 30     Comedy           Family        Animation              NaN        NaN
# 31  Adventure          Fantasy  Science Fiction              NaN        NaN
# 32  Animation            Music           Comedy            Drama        NaN
# 33  Adventure  Science Fiction          Fantasy              NaN        NaN
# 34  Adventure        Animation           Comedy           Family        NaN
# 35      Drama          Romance            Music              NaN        NaN
# 36  Adventure          Fantasy              NaN              NaN        NaN
# 37   Thriller              NaN              NaN              NaN        NaN
# 38  Animation           Family           Comedy  Science Fiction        NaN
# 39     Action        Adventure              NaN              NaN        NaN
# 40    Fantasy          Romance              NaN              NaN        NaN
# 41      Crime         Thriller              NaN              NaN        NaN
# 42  Animation           Comedy           Family        Adventure        NaN
# 43  Adventure           Comedy          Fantasy              NaN        NaN
# 44  Adventure  Science Fiction            Drama              NaN        NaN
# 45     Action            Drama              NaN              NaN        NaN
# 46     Action  Science Fiction           Comedy              NaN        NaN
# 47  Adventure           Comedy          Fantasy  Science Fiction        NaN
# 48  Adventure          Fantasy              NaN              NaN        NaN
# 49  Animation          Fantasy            Music           Comedy  Adventure
#
#        Revenue  Box Office     Budget  TMDb Score  IMDb  Rotten Tomatoes  \
# 0   2068223624   936662225  245000000         7.4   7.9             93.0
# 1   1671713208   652385625  150000000         6.7   7.0             70.0
# 2   1515047671   353007020  190000000         7.3   7.1             82.0
# 3   1405403694   459005868  250000000         7.3   7.3             75.0
# 4   1156730962   336045770   74000000         6.4   6.4             55.0
# 5    880674609   200074609  245000000         6.5   6.8             63.0
# 6    857611174   356921711  175000000         7.9   8.1             98.0
# 7    682330139   195042377  150000000         7.2   7.4             94.0
# 8    653428261   281723902  160000000         6.9   6.6             69.0
# 9    630161890   228433663  108000000         7.7   8.0             91.0
# 10   571006128   166167230    4000000         5.9   4.1             24.0
# 11   543514353   201151353   95000000         6.8   6.9             83.0
# 12   532950503   183637894  135000000         7.5   8.0             78.0
# 13   519311965   180202163  130000000         7.1   7.3             82.0
# 14   473990832   155190832  110000000         6.2   6.1             49.0
# 15   473226958   169700110   80000000         6.8   6.7             55.0
# 16   440603537    89760956  155000000         5.9   6.3             27.0
# 17   378858340   154058340  150000000         7.5   8.1             97.0
# 18   368871007   177397510  135000000         6.8   6.6             51.0
# 19   332207671   123087120  175000000         6.7   6.7             76.0
# 20  1153296293   408084349  250000000         7.4   7.8             90.0
# 21  1056057273   532177324  200000000         7.5   7.8             84.0
# 22  1028570889   486295561  200000000         7.1   7.3             94.0
# 23  1023784195   341268248  150000000         7.7   8.0             98.0
# 24   966550600   364001123  175000000         6.9   7.4             94.0
# 25   875457937   368384330   75000000         6.2   6.5             72.0
# 26   873634919   330360194  250000000         5.9   6.4             29.0
# 27   809342332   234037575  180000000         7.4   7.3             74.0
# 28   783100000   363070709   58000000         7.6   8.0             85.0
# 29   746846894   325100054  175000000         5.9   6.0             26.0
# 30   690860472   248757044  150000000         7.6   7.6             95.0
# 31   677700000   232641920  165000000         7.4   7.5             89.0
# 32   634151679   270448425   75000000         7.1   7.1             72.0
# 33   543934787   155442489  178000000         6.5   6.9             47.0
# 34   521170825   143528619  145000000         6.8   7.1             87.0
# 35   446486224   151101803   30000000         7.9   8.0             90.0
# 36   433677183    47365290  160000000         6.3   6.8             28.0
# 37   415484914   162434410  120000000         6.3   6.6             54.0
# 38   408579038    64063008  105000000         6.0   5.7             18.0
# 39  1332539889   620181382  200000000         6.9   7.0             90.0
# 40  1263521126   504481165  160000000         7.0   7.1             71.0
# 41  1238764765   226008385  250000000         6.9   6.6             67.0
# 42  1031552585   264624300   80000000         6.4   6.3             58.0
# 43   962102237   404540171   90000000         6.8   6.9             76.0
# 44   880166924   334201140  175000000         7.4   7.4             92.0
# 45   870322670     2721100   29700000         6.6   6.0             69.0
# 46   863756051   389813101  200000000         7.6   7.6             85.0
# 47   853977126   315058289  180000000         7.6   7.9             93.0
# 48   821847012   412815408  149000000         7.3   7.4             93.0
# 49   800526015   210460015  175000000         8.2   8.4             97.0
#
#     Metascore                                             Awards  \
# 0        80.0  Nominated for 5 Oscars. Another 62 wins & 131 ...
# 1        59.0                          15 wins & 58 nominations.
# 2        67.0  Nominated for 1 Golden Globe. Another 35 wins ...
# 3        66.0                           8 wins & 49 nominations.
# 4        56.0  Nominated for 1 BAFTA Film Award. Another 4 wi...
# 5        60.0      Won 1 Oscar. Another 7 wins & 36 nominations.
# 6        94.0    Won 1 Oscar. Another 99 wins & 116 nominations.
# 7        75.0                           6 wins & 26 nominations.
# 8        65.0                          16 wins & 34 nominations.
# 9        80.0  Nominated for 7 Oscars. Another 38 wins & 192 ...
# 10       46.0  Nominated for 1 Oscar. Another 9 wins & 27 nom...
# 11       67.0  Nominated for 1 Oscar. Another 8 wins & 36 nom...
# 12       76.0   Won 3 Oscars. Another 88 wins & 187 nominations.
# 13       64.0  Nominated for 1 BAFTA Film Award. Another 4 wi...
# 14       43.0                           2 wins & 10 nominations.
# 15       44.0                            1 win & 10 nominations.
# 16       38.0                                    10 nominations.
# 17       90.0  Won 6 Oscars. Another 239 wins & 231 nominations.
# 18       55.0                            3 wins & 9 nominations.
# 19       66.0  Nominated for 1 Golden Globe. Another 9 wins &...
# 20       75.0                          16 wins & 72 nominations.
# 21       65.0  Nominated for 2 Oscars. Another 24 wins & 81 n...
# 22       77.0  Nominated for 1 BAFTA Film Award. Another 17 w...
# 23       78.0     Won 1 Oscar. Another 46 wins & 72 nominations.
# 24       77.0     Won 1 Oscar. Another 32 wins & 54 nominations.
# 25       61.0                           4 wins & 15 nominations.
# 26       44.0                          14 wins & 33 nominations.
# 27       66.0     Won 1 Oscar. Another 14 wins & 54 nominations.
# 28       65.0  Nominated for 2 Golden Globes. Another 28 wins...
# 29       40.0     Won 1 Oscar. Another 16 wins & 40 nominations.
# 30       81.0  Nominated for 2 Oscars. Another 20 wins & 88 n...
# 31       72.0  Nominated for 1 Oscar. Another 19 wins & 67 no...
# 32       59.0  Nominated for 2 Golden Globes. Another 3 wins ...
# 33       52.0                            1 win & 19 nominations.
# 34       66.0                            1 win & 10 nominations.
# 35       94.0  Won 6 Oscars. Another 236 wins & 287 nominations.
# 36       32.0                            2 wins & 3 nominations.
# 37       58.0                           3 wins & 20 nominations.
# 38       34.0                                            2 wins.
# 39       84.0  Nominated for 4 Oscars. Another 26 wins & 99 n...
# 40       65.0  Nominated for 2 Oscars. Another 15 wins & 72 n...
# 41       56.0                           2 wins & 12 nominations.
# 42       49.0                                    33 nominations.
# 43       58.0                           6 wins & 19 nominations.
# 44       73.0                           7 wins & 10 nominations.
# 45       44.0                          27 wins & 15 nominations.
# 46       67.0  Nominated for 1 Oscar. Another 15 wins & 57 no...
# 47       74.0                           6 wins & 50 nominations.
# 48       76.0                          25 wins & 72 nominations.
# 49       81.0   Won 2 Oscars. Another 109 wins & 40 nominations.
#
#     Release Year  Release Month
# 0           2015             12
# 1           2015              6
# 2           2015              4
# 3           2015              4
# 4           2015              6
# 5           2015             10
# 6           2015              6
# 7           2015              7
# 8           2015             11
# 9           2015              9
# 10          2015              2
# 11          2015              3
# 12          2015             12
# 13          2015              7
# 14          2015              5
# 15          2015              9
# 16          2015              6
# 17          2015              5
# 18          2015              3
# 19          2015             11
# 20          2016              4
# 21          2016             12
# 22          2016              6
# 23          2016              2
# 24          2016              4
# 25          2016              6
# 26          2016              3
# 27          2016             11
# 28          2016              2
# 29          2016              8
# 30          2016             11
# 31          2016             10
# 32          2016             11
# 33          2016              5
# 34          2016              1
# 35          2016             11
# 36          2016              5
# 37          2016              7
# 38          2016              6
# 39          2017             12
# 40          2017              3
# 41          2017              4
# 42          2017              6
# 43          2017             12
# 44          2017              7
# 45          2017              7
# 46          2017              4
# 47          2017             10
# 48          2017              5
# 49          2017             10

# %%
#all_df["Genre"] = all_df["Genre_1"] + " " + all_df["Genre_2"] 

clean_df = all_df[["Title","Budget","Revenue","Rotten Tomatoes","IMDb","Awards","Release Year","Genre_1"]]

clean_df.head(10)
# Out:
#                                    Title     Budget     Revenue  \
# 0           Star Wars: The Force Awakens  245000000  2068223624
# 1                         Jurassic World  150000000  1671713208
# 2                              Furious 7  190000000  1515047671
# 3                Avengers: Age of Ultron  250000000  1405403694
# 4                                Minions   74000000  1156730962
# 5                                Spectre  245000000   880674609
# 6                             Inside Out  175000000   857611174
# 7     Mission: Impossible - Rogue Nation  150000000   682330139
# 8  The Hunger Games: Mockingjay - Part 2  160000000   653428261
# 9                            The Martian  108000000   630161890
#
#    Rotten Tomatoes  IMDb                                             Awards  \
# 0             93.0   7.9  Nominated for 5 Oscars. Another 62 wins & 131 ...
# 1             70.0   7.0                          15 wins & 58 nominations.
# 2             82.0   7.1  Nominated for 1 Golden Globe. Another 35 wins ...
# 3             75.0   7.3                           8 wins & 49 nominations.
# 4             55.0   6.4  Nominated for 1 BAFTA Film Award. Another 4 wi...
# 5             63.0   6.8      Won 1 Oscar. Another 7 wins & 36 nominations.
# 6             98.0   8.1    Won 1 Oscar. Another 99 wins & 116 nominations.
# 7             94.0   7.4                           6 wins & 26 nominations.
# 8             69.0   6.6                          16 wins & 34 nominations.
# 9             91.0   8.0  Nominated for 7 Oscars. Another 38 wins & 192 ...
#
#    Release Year    Genre_1
# 0          2015     Action
# 1          2015     Action
# 2          2015     Action
# 3          2015     Action
# 4          2015     Family
# 5          2015     Action
# 6          2015  Animation
# 7          2015     Action
# 8          2015     Action
# 9          2015      Drama

# %%
html = clean_df.to_html()
text_file = open("Data.html", "w")
text_file.write(html)
text_file.close()

# %%
action_df = clean_df.loc[clean_df["Genre_1"] == "Action"]
action_df.head(10)
# Out:
#                                     Title     Budget     Revenue  \
# 0            Star Wars: The Force Awakens  245000000  2068223624
# 1                          Jurassic World  150000000  1671713208
# 2                               Furious 7  190000000  1515047671
# 3                 Avengers: Age of Ultron  250000000  1405403694
# 5                                 Spectre  245000000   880674609
# 7      Mission: Impossible - Rogue Nation  150000000   682330139
# 8   The Hunger Games: Mockingjay - Part 2  160000000   653428261
# 14                            San Andreas  110000000   473990832
# 17                     Mad Max: Fury Road  150000000   378858340
# 21           Rogue One: A Star Wars Story  200000000  1056057273
#
#     Rotten Tomatoes  IMDb                                             Awards  \
# 0              93.0   7.9  Nominated for 5 Oscars. Another 62 wins & 131 ...
# 1              70.0   7.0                          15 wins & 58 nominations.
# 2              82.0   7.1  Nominated for 1 Golden Globe. Another 35 wins ...
# 3              75.0   7.3                           8 wins & 49 nominations.
# 5              63.0   6.8      Won 1 Oscar. Another 7 wins & 36 nominations.
# 7              94.0   7.4                           6 wins & 26 nominations.
# 8              69.0   6.6                          16 wins & 34 nominations.
# 14             49.0   6.1                           2 wins & 10 nominations.
# 17             97.0   8.1  Won 6 Oscars. Another 239 wins & 231 nominations.
# 21             84.0   7.8  Nominated for 2 Oscars. Another 24 wins & 81 n...
#
#     Release Year Genre_1
# 0           2015  Action
# 1           2015  Action
# 2           2015  Action
# 3           2015  Action
# 5           2015  Action
# 7           2015  Action
# 8           2015  Action
# 14          2015  Action
# 17          2015  Action
# 21          2016  Action

# %%
family_df = clean_df.loc[clean_df["Genre_1"] == "Family"]
family_df.head(12)
# Out:
#                            Title     Budget     Revenue  Rotten Tomatoes  \
# 4                        Minions   74000000  1156730962             55.0
# 15          Hotel Transylvania 2   80000000   473226958             55.0
# 32                          Sing   75000000   634151679             72.0
# 40          Beauty and the Beast  160000000  1263521126             71.0
# 49                          Coco  175000000   800526015             97.0
# 73     Ralph Breaks the Internet  175000000   529221154             88.0
# 80                     Frozen II  150000000  1450026933             78.0
# 90  Maleficent: Mistress of Evil  185000000   491570967             39.0
#
#     IMDb                                             Awards  Release Year  \
# 4    6.4  Nominated for 1 BAFTA Film Award. Another 4 wi...          2015
# 15   6.7                            1 win & 10 nominations.          2015
# 32   7.1  Nominated for 2 Golden Globes. Another 3 wins ...          2016
# 40   7.1  Nominated for 2 Oscars. Another 15 wins & 72 n...          2017
# 49   8.4   Won 2 Oscars. Another 109 wins & 40 nominations.          2017
# 73   7.0  Nominated for 1 Oscar. Another 3 wins & 66 nom...          2018
# 80   6.9  Nominated for 1 Oscar. Another 18 wins & 88 no...          2019
# 90   6.6  Nominated for 1 Oscar. Another 1 win & 10 nomi...          2019
#
#    Genre_1
# 4   Family
# 15  Family
# 32  Family
# 40  Family
# 49  Family
# 73  Family
# 80  Family
# 90  Family

# %%
sf_df = clean_df.loc[clean_df["Genre_1"] == "Science Fiction"]
sf_df.head(10)
# Out:
#                              Title     Budget     Revenue  Rotten Tomatoes  \
# 13                         Ant-Man  130000000   519311965             82.0
# 16              Terminator Genisys  155000000   440603537             27.0
# 39        Star Wars: The Last Jedi  200000000  1332539889             90.0
# 65                           Venom  116000000   855013954             29.0
# 70                Ready Player One  175000000   582890172             72.0
# 94  Godzilla: King of the Monsters  170000000   386600138             42.0
#
#     IMDb                                             Awards  Release Year  \
# 13   7.3  Nominated for 1 BAFTA Film Award. Another 4 wi...          2015
# 16   6.3                                    10 nominations.          2015
# 39   7.0  Nominated for 4 Oscars. Another 26 wins & 99 n...          2017
# 65   6.7                            3 wins & 9 nominations.          2018
# 70   7.4  Nominated for 1 Oscar. Another 11 wins & 55 no...          2018
# 94   6.0                           6 wins & 14 nominations.          2019
#
#             Genre_1
# 13  Science Fiction
# 16  Science Fiction
# 39  Science Fiction
# 65  Science Fiction
# 70  Science Fiction
# 94  Science Fiction

# %%
adventure_df = clean_df.loc[clean_df["Genre_1"] == "Adventure"]
adventure_df.head(10)
# Out:
#                                                Title     Budget     Revenue  \
# 19                                 The Good Dinosaur  175000000   332207671
# 20                        Captain America: Civil War  250000000  1153296293
# 22                                      Finding Dory  200000000  1028570889
# 24                                   The Jungle Book  175000000   966550600
# 25                           The Secret Life of Pets   75000000   875457937
# 27           Fantastic Beasts and Where to Find Them  180000000   809342332
# 30                                             Moana  150000000   690860472
# 38                         Ice Age: Collision Course  105000000   408579038
# 46                    Guardians of the Galaxy Vol. 2  200000000   863756051
# 50  Pirates of the Caribbean: Dead Men Tell No Tales  230000000   794861794
#
#     Rotten Tomatoes  IMDb                                             Awards  \
# 19             76.0   6.7  Nominated for 1 Golden Globe. Another 9 wins &...
# 20             90.0   7.8                          16 wins & 72 nominations.
# 22             94.0   7.3  Nominated for 1 BAFTA Film Award. Another 17 w...
# 24             94.0   7.4     Won 1 Oscar. Another 32 wins & 54 nominations.
# 25             72.0   6.5                           4 wins & 15 nominations.
# 27             74.0   7.3     Won 1 Oscar. Another 14 wins & 54 nominations.
# 30             95.0   7.6  Nominated for 2 Oscars. Another 20 wins & 88 n...
# 38             18.0   5.7                                            2 wins.
# 46             85.0   7.6  Nominated for 1 Oscar. Another 15 wins & 57 no...
# 50             29.0   6.5                            1 win & 13 nominations.
#
#     Release Year    Genre_1
# 19          2015  Adventure
# 20          2016  Adventure
# 22          2016  Adventure
# 24          2016  Adventure
# 25          2016  Adventure
# 27          2016  Adventure
# 30          2016  Adventure
# 38          2016  Adventure
# 46          2017  Adventure
# 50          2017  Adventure

# %%
genre = clean_df.groupby(["Genre_1"])
genre_df = genre.count()
genre_df.head(30)
# Out:
#                  Title  Budget  Revenue  Rotten Tomatoes  IMDb  Awards  \
# Genre_1
# Action              44      44       44               44    44      44
# Adventure           17      17       17               17    17      17
# Animation            6       6        6                6     6       6
# Comedy               1       1        1                1     1       1
# Crime                1       1        1                1     1       1
# Drama                4       4        4                4     4       4
# Family               8       8        8                8     8       8
# Fantasy              1       1        1                1     1       1
# Horror               2       2        2                2     2       2
# Music                1       1        1                1     1       1
# Romance              1       1        1                1     1       1
# Science Fiction      6       6        6                6     6       6
# War                  3       3        3                3     3       3
# Western              1       1        1                1     1       1
#
#                  Release Year
# Genre_1
# Action                     44
# Adventure                  17
# Animation                   6
# Comedy                      1
# Crime                       1
# Drama                       4
# Family                      8
# Fantasy                     1
# Horror                      2
# Music                       1
# Romance                     1
# Science Fiction             6
# War                         3
# Western                     1

# %%
genre_analysis=clean_df.groupby(["Genre_1"])\
    .agg({"Title":"size", "Budget":"mean", "Revenue":"mean", "IMDb":"mean"})\
    .rename(columns={"Title":"Title_count","Budget":"Budget_mean","Revenue":"Revenue_mean","IMDb":"IMDb_mean"})\
    .sort_values(by="Title_count", ascending=False)\
    .reset_index()

genre_analysis.head(15)
# Out:
#             Genre_1  Title_count   Budget_mean  Revenue_mean  IMDb_mean
# 0            Action           44  1.667955e+08  8.508214e+08   6.965909
# 1         Adventure           17  1.964118e+08  1.058553e+09   7.176471
# 2            Family            8  1.342500e+08  8.498720e+08   7.025000
# 3         Animation            6  1.090000e+08  6.820632e+08   7.283333
# 4   Science Fiction            6  1.576667e+08  6.861599e+08   6.783333
# 5             Drama            4  7.450000e+07  5.308977e+08   6.775000
# 6               War            3  7.656667e+07  5.902099e+08   7.366667
# 7            Horror            2  5.700000e+07  5.874448e+08   6.900000
# 8            Comedy            1  3.000000e+07  4.464862e+08   8.000000
# 9             Crime            1  5.500000e+07  1.074251e+09   8.400000
# 10          Fantasy            1  1.350000e+08  3.688710e+08   6.600000
# 11            Music            1  5.200000e+07  8.940275e+08   8.000000
# 12          Romance            1  9.500000e+07  5.435144e+08   6.900000
# 13          Western            1  1.350000e+08  5.329505e+08   8.000000

# %%
genre_pie = ["Action", "Adventure", "Family", "Science Fiction", "Other"]
numbers = [44, 17, 8, 6, 21]
explode = (0.05, 0, 0, 0, 0)
colors = ["aquamarine", "dodgerblue", "violet", "gold", "coral"]
plt.figure(figsize = (7,7))
plt.axis("equal")
plt.pie(numbers, labels = genre_pie, colors = colors, explode=explode, autopct="%1.1f%%", shadow = True, textprops={'fontsize': 14})
plt.show()
plt.savefig("Images/Distribution_Genres.png")

# %%
x = action_df["Budget"]
y = action_df["Revenue"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

plt.title("Budget vs. Revenue | Action Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("Revenue (billions)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

#F string the slope is, the intercept is, the r value is (don't round!)

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.25, .5), xycoords="axes fraction", color = "red", fontsize =20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Revenue_ActionMovies.png")
.
plt.show()
# Out:
# The r-squared value is: 0.37337653559717365
# The slope is: 2.7003163127413945
# The Y-Intercept is: 400420893.40433884

# %%
x = action_df["Budget"]
y = action_df["IMDb"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

plt.title("Budget vs. IMDb Ratings | Action Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDb Ratings")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.25, .3), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Ratings_ActionMovies.png")

plt.show()
# Out:
# The r-squared value is: -0.11947908242985701
# The slope is: -1.5215015183096764e-09
# The Y-Intercept is: 7.219688628247154

# %%
x = family_df["Budget"]
y = family_df["Revenue"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

#plt.xlim(7.4, 8.0)
#plt.ylim(.50, 2.00)

plt.title("Budget vs. Revenue | Family Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("Revenue (billions)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.15, .5), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Revenue_FamilyMovies.png")

plt.show()
# Out:
# The r-squared value is: 0.011794927394165025
# The slope is: 0.09288263259627623
# The Y-Intercept is: 837402480.8239499

# %%
x = family_df["Budget"]
y = family_df["IMDb"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

plt.title("Budget vs. IMDb Ratings | Family Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDb Ratings")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.25, .5), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Ratings_FamilyMovies.png")

plt.show()
# Out:
# The r-squared value is: 0.40240847592801
# The slope is: 4.987715715004587e-09
# The Y-Intercept is: 6.355399165260635

# %%
x = sf_df["Budget"]
y = sf_df["Revenue"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

plt.title("Budget vs. Revenue | Science Fiction Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("Revenue (billions)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.15, .3), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Revenue_ScienceFictionMovies.png")

plt.show()
# Out:
# The r-squared value is: 0.3661559535625699
# The slope is: 4.231598479102384
# The Y-Intercept is: 18977915.628190756

# %%
x = sf_df["Budget"]
y = sf_df["IMDb"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

#plt.xlim(7.4, 8.0)
#plt.ylim(.50, 2.00)

plt.title("Budget vs. IMDb Ratings | Science Fiction Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDb Ratings")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.25, .3), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Ratings_ScienceFictionMovies.png")

plt.show()
# Out:
# The r-squared value is: 0.007771008316512648
# The slope is: 1.4025245441795344e-10
# The Y-Intercept is: 6.761220196353436

# %%
x = adventure_df["Budget"]
y = adventure_df["Revenue"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

plt.title("Budget vs. Revenue | Adventure Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("Revenue (billions)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.15, .5), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Revenue_AdventureMovies.png")

plt.show()
# Out:
# The r-squared value is: 0.8201201313625246
# The slope is: 7.203430377221383
# The Y-Intercept is: -356285204.5024823

# %%
x = adventure_df["Budget"]
y = adventure_df["IMDb"]

plt.scatter(x, y, edgecolors = 'black', linewidths=1, marker="o")

plt.title("Budget vs. IMDb Ratings | Adventure Movies 2015 - 2019")
plt.xlabel("Budget (millions)")
plt.ylabel("IMDb Ratings")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 

analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")

plt.annotate(analysis, xy=(.38, .3), xycoords="axes fraction", color = "red", fontsize = 20)

print(f"The r-squared value is: {rvalue}")
print(f"The slope is: {slope}")
print(f"The Y-Intercept is: {intercept}")

plt.savefig("Images/Budget_Ratings_AdeventureMovies.png")

plt.show()
# Out:
# The r-squared value is: 0.685034012888139
# The slope is: 7.159200894938582e-09
# The Y-Intercept is: 5.770319306576475

# %%
#Create dataframe with only top 10 grossing films for action movies
action_sml = action_df[["Title", "Budget", "Revenue"]]
top_action = action_sml.sort_values(by=["Revenue"], ascending = False)
test_top_action = top_action[0:10]
test_top_action
# Out:
#                              Title     Budget     Revenue
# 0     Star Wars: The Force Awakens  245000000  2068223624
# 1                   Jurassic World  150000000  1671713208
# 2                        Furious 7  190000000  1515047671
# 3          Avengers: Age of Ultron  250000000  1405403694
# 60                   Black Panther  200000000  1346739107
# 61  Jurassic World: Fallen Kingdom  170000000  1303459585
# 62                   Incredibles 2  200000000  1242805359
# 41         The Fate of the Furious  250000000  1238764765
# 63                         Aquaman  160000000  1148461807
# 81       Spider-Man: Far from Home  160000000  1131927996

# %%
#Create dataframe with only bottom 10 grossing films for action movies
bottom_action = action_sml.sort_values(by=["Revenue"], ascending = True)
test_bottom_action = bottom_action[0:10]
test_bottom_action
# Out:
#                         Title     Budget    Revenue
# 17         Mad Max: Fury Road  150000000  378858340
# 93        Alita: Battle Angel  170000000  404852543
# 37               Jason Bourne  120000000  415484914
# 77                    Rampage  120000000  426245950
# 92  Pokémon Detective Pikachu  150000000  433005346
# 36                   Warcraft  160000000  433677183
# 75                  Bumblebee  135000000  467989645
# 14                San Andreas  110000000  473990832
# 34            Kung Fu Panda 3  145000000  521170825
# 72                    The Meg  150000000  530243742

# %%
#Create dataframe with only top 10 grossing films for adventure movies
adventure_sml = adventure_df[["Title", "Budget", "Revenue"]]
top_adventure = adventure_sml.sort_values(by=["Revenue"], ascending = False)
test_top_adventure = top_adventure[0:10]
test_top_adventure
# Out:
#                              Title     Budget     Revenue
# 78               Avengers: Endgame  356000000  2797800564
# 59          Avengers: Infinity War  300000000  2046239637
# 79                   The Lion King  260000000  1656943394
# 20      Captain America: Civil War  250000000  1153296293
# 85                     Toy Story 4  175000000  1073394593
# 86                         Aladdin  183000000  1047612394
# 22                    Finding Dory  200000000  1028570889
# 24                 The Jungle Book  175000000   966550600
# 25         The Secret Life of Pets   75000000   875457937
# 46  Guardians of the Galaxy Vol. 2  200000000   863756051

# %%
#Create dataframe with only bottom 10 grossing films for action movies
bottom_adventure = adventure_sml.sort_values(by=["Revenue"], ascending = True)
test_bottom_adventure = bottom_adventure[0:10]
test_bottom_adventure
# Out:
#                                                Title     Budget    Revenue
# 19                                 The Good Dinosaur  175000000  332207671
# 38                         Ice Age: Collision Course  105000000  408579038
# 68       Fantastic Beasts: The Crimes of Grindelwald  200000000  653355901
# 30                                             Moana  150000000  690860472
# 50  Pirates of the Caribbean: Dead Men Tell No Tales  230000000  794861794
# 87                           Jumanji: The Next Level  125000000  796575993
# 27           Fantastic Beasts and Where to Find Them  180000000  809342332
# 46                    Guardians of the Galaxy Vol. 2  200000000  863756051
# 25                           The Secret Life of Pets   75000000  875457937
# 24                                   The Jungle Book  175000000  966550600
